# %%
import findspark
findspark.init()
findspark.find()

import pyspark
findspark.find()
# Out:
# 'C:\\Spark\\spark-3.1.2-bin-hadoop3.2'

# %%
#Initialize SparkSession and SparkContext
from pyspark.sql import SparkSession

#Create a Spark Session
spark = SparkSession \
    .builder \
    .master("local[1]") \
    .appName("MyFirstJob") \
    .config("spark.executor.memory", "4g") \
    .config("spark.cores.max","2") \
    .enableHiveSupport() \
    .getOrCreate()

#Get the Spark Context from Spark Session    
sc = spark.sparkContext

print("Spark context init done.")
# Out:
# Spark context init done.

# %%
data = ["Project","Gutenberg’s","Alice’s","Adventures",
"in","Wonderland","Project","Gutenberg’s","Adventures",
"in","Wonderland","Project","Gutenberg’s"]

rdd=spark.sparkContext.parallelize(data)

# %%
#Hacemos una prueba de que la sesión de Spark funciona

rdd2=rdd.map(lambda x: (x,1))
for element in rdd2.collect():
    print(element)
# Out:
# ('Project', 1)
# ('Gutenberg’s', 1)
# ('Alice’s', 1)
# ('Adventures', 1)
# ('in', 1)
# ('Wonderland', 1)
# ('Project', 1)
# ('Gutenberg’s', 1)
# ('Adventures', 1)
# ('in', 1)
# ('Wonderland', 1)
# ('Project', 1)
# ('Gutenberg’s', 1)

# %%
# Leemos el fichero con textFile
date = "20220616"

rddMovies = sc.textFile("./landing/movies/date=" + date + "/movies.csv")
rddFollows = sc.textFile("./landing/movies/date=" + date + "/followsClean.csv")
rddLikes = sc.textFile("./landing/movies/date=" + date + "/likesClean.csv")


listMovies = rddMovies.collect()
for movie in listMovies:
    print(movie)

# %%
listFollows = rddFollows.collect()
for follow in listFollows:
    print(follow)

# %%
listLikes = rddLikes.collect()
for like in listLikes:
    print(like)

# %%
def isEmpty(x):
    if (x == None or len(x) == 0):
        return True
    else:
        return False
    
def isNumber(x):
    # Si no se puede castear a float devolvemos 0, que consideraremos un valor no válido
    try:
        return float(x)
    except:
        return 0
    


def validate(x):
    register = x[0]
    user = x[1]
    title = x[2]
    year = x[3]
    score = x[4]
    users_rating = x[5]
    votes = x[6]
    metascore = x[7]
    codirector = x[8]
    director = x[9]
    cogenre = x[10]
    genre = x[11]
    mainactor = x[12]
    secactor = x[13]
    seclanguage = x[14]
    vose = x[15]
    country = x[16]
    seccountry = x[17]


    
    # Serán buenos solamente los elementos del rdd que tienen good
    outputValidation = "good"
    
    if isEmpty(score):
        outputValidation = "badByEmpty"
        x[4] = 0
        
    if outputValidation == "good" and not isNumber(year) or not isNumber(score) or not isNumber(users_rating) or not isNumber(metascore):
        outputValidation = "badByNumber"         
        
    x.append(outputValidation)
    x.append(date)
    
    return x


def castTypes(x):
    x[3] = int(float(x[3]))
    x[4] = float(x[4])
    x[5] = float(x[5])
    x[7] = int(float(x[7]))

    
    return x

# %%
register
user
title
year
score
users_rating
votes
metascore
codirector
director
cogenre
genre
mainactor
secactor
seclanguage
vose
country
seccountry

# %%
# Leemos el fichero con textFile
date = "20220616"

rddMovies = sc.textFile("./landing/movies/date=" + date + "/movies.csv")
header = rddMovies.first()
rddMovies = rddMovies.filter(lambda x: x != header).repartition(1)

# Reemplazar comas que forman parte de la misma columna
rddMoviesValidated = rddMovies.map(lambda x: x.split(',')).map(validate)
    
rddMoviesOk = rddMoviesValidated.filter(lambda x : x[18] == "good").map(castTypes)
rddMoviesKo = rddMoviesValidated.filter(lambda x : x[18] != "good")
rddMoviesOk.repartition(4).saveAsTextFile("./staging/moviesok/date=" + date + "/")
rddMoviesKo.repartition(4).saveAsTextFile("./staging/moviesko/date=" + date + "/")
rddMoviesKo = rddMoviesKo.map(castTypes)

# %%
listMovies = rddMoviesOk.collect()
for movie in listMovies:
    print(movie)
# Out:
# ['7', 'julcarbad6@jazztel.com', 'Serenity', 2005, 2.0, 7.8, '32119', 74, '', 'Joss Whedon', 'Adventure', 'Action', 'Nathan Fillion', 'Gina Torres', 'Mandarin', 'English', 'USA', '', 'good', '20220616']
# ['10', 'eleirssas26@gmail.com', 'The Ides of March', 2011, 8.0, 7.100004252644909, '211633', 67, '', 'George Clooney', 'Thriller', 'Drama', 'Ryan Gosling', 'George Clooney', '', 'English', 'USA', '', 'good', '20220616']
# ['26', 'josdasvig2879@orange.com', 'The Ring Two', 2005, 9.0, 5.400040160642571, '89640', 44, '', 'Hideo Nakata', 'Mystery', 'Horror', 'Naomi Watts', 'Simon Baker', '', 'English', 'USA', '', 'good', '20220616']
# ['28', 'guemaiiva047323@vodafone.com ', "Madagascar 3: Europe's Most Wanted", 2012, 7.0, 6.800001271229532, '157328', 60, 'Tom McGrath', 'Eric Darnell', 'Adventure', 'Animation', 'Ben Stiller', 'Chris Rock', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['38', 'joasantey6285@orange.com', 'Where Hope Grows', 2014, 10.0, 6.60117973629424, '2882', 41, '', 'Chris Dowling', 'Family', 'Drama', 'Kristoffer Polaha', 'David DeSanctis', '', 'English', 'USA', '', 'good', '20220616']
# ['40', 'alifenvel96289@vodafone.com ', 'White Rabbit', 2018, 7.0, 5.701113967437875, '1167', 61, '', 'Daryl Wein', 'Drama', 'Comedy', 'Vivian Bang', 'Nana Ghana', '', 'English', 'USA', '', 'good', '20220616']
# ['41', 'marmaybaz2601@movistar.com', 'Thin Ice', 2011, 1.0, 6.19886114761279, '4566', 60, '', 'Jill Sprecher', 'Crime', 'Comedy', 'Greg Kinnear', 'John Paul Gamoke', '', 'English', 'USA', '', 'good', '20220616']
# ['42', 'jacavioli86730@vodafone.com ', 'In the Blood', 2014, 8.0, 5.70020882513165, '11014', 40, '', 'John Stockwell', 'Crime', 'Action', 'Gina Carano', 'Cam Gigandet', '', 'English', 'UK', 'Puerto Rico', 'good', '20220616']
# ['48', 'humpenpor2@orange.com', 'Amadeus', 1984, 10.0, 8.30000475669505, '357391', 88, '', 'Milos Forman', 'Drama', 'Biography', 'F. Murray Abraham', 'Tom Hulce', 'Italian', 'English', 'USA', 'France', 'good', '20220616']
# ['62', 'guiurdfel76@digi.com', 'The Pyramid', 2014, 5.0, 4.600017730496454, '22560', 24, '', 'Grégory Levasseur', 'Adventure', 'Action', 'Ashley Hinshaw', "Denis O'Hare", '', 'English', 'USA', 'Morocco', 'good', '20220616']
# ['64', 'aleechgua159671@movistar.com', 'Rogue One: A Star Wars Story', 2016, 7.0, 7.799998497536899, '532459', 65, '', 'Gareth Edwards', 'Adventure', 'Action', 'Felicity Jones', 'Diego Luna', '', 'English', 'USA', '', 'good', '20220616']
# ['68', 'gemyanbic970@hotmail.com', 'The African Queen', 1951, 9.0, 7.700018701806883, '69512', 91, '', 'John Huston', 'Drama', 'Adventure', 'Humphrey Bogart', 'Katharine Hepburn', 'German', 'English', 'UK', 'USA', 'good', '20220616']
# ['69', 'alifenvel96289@vodafone.com ', 'Aniara', 2018, 2.0, 6.199105812220567, '4697', 61, 'Hugo Lilja', 'Pella Kagerman', 'Sci-Fi', 'Drama', 'Emelie Garbers', 'Bianca Cruzeiro', 'Spanish', 'Swedish', 'Sweden', 'Denmark', 'good', '20220616']
# ['85', 'adidialar3@digi.com', 'Sliver', 1993, 10.0, 5.000177582042904, '28156', 38, '', 'Phillip Noyce', 'Thriller', 'Drama', 'Sharon Stone', 'William Baldwin', '', 'English', 'USA', '', 'good', '20220616']
# ['89', 'xesmalref0@digi.com', 'The Hollars', 2016, 10.0, 6.500318095064983, '11003', 53, '', 'John Krasinski', 'Drama', 'Comedy', 'Margo Martindale', 'Sharlto Copley', '', 'English', 'USA', '', 'good', '20220616']
# ['98', 'yahkniple6@orange.com', 'Bandits', 2001, 5.0, 6.49997666677037, '64286', 60, '', 'Barry Levinson', 'Crime', 'Comedy', 'Bruce Willis', 'Billy Bob Thornton', '', 'English', 'USA', '', 'good', '20220616']
# ['100', 'julcarbad6@jazztel.com', 'Sabotage', 2014, 4.0, 5.699970559201982, '57743', 41, '', 'David Ayer', 'Crime', 'Action', 'Arnold Schwarzenegger', 'Sam Worthington', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['106', 'adidialar3@digi.com', 'Labor Day', 2013, 3.0, 6.899905410977177, '41231', 52, '', 'Jason Reitman', 'Romance', 'Drama', 'Kate Winslet', 'Josh Brolin', '', 'English', 'USA', '', 'good', '20220616']
# ['114', 'gemyanbic970@hotmail.com', 'Opening Night', 1977, 10.0, 8.000233263354326, '8574', 69, '', 'John Cassavetes', '', 'Drama', 'Gena Rowlands', 'John Cassavetes', '', 'English', 'USA', '', 'good', '20220616']
# ['117', 'julharsel07108@orange.com', 'The Gumball Rally', 1976, 10.0, 6.3010384507437545, '3563', 37, '', 'Charles Bail', '', 'Comedy', 'Michael Sarrazin', 'Norman Burton', 'Italian', 'English', 'USA', '', 'good', '20220616']
# ['118', 'lucboufan4887@hotmail.com', 'Iris', 2001, 2.0, 6.999703686144364, '16874', 76, '', 'Richard Eyre', 'Drama', 'Biography', 'Kate Winslet', 'Hugh Bonneville', '', 'English', 'UK', 'USA', 'good', '20220616']
# ['123', 'almfetest52084@jazztel.com', 'The Girl on the Train', 2016, 5.0, 6.499990795004756, '162955', 48, '', 'Tate Taylor', 'Drama', 'Crime', 'Emily Blunt', 'Haley Bennett', 'Spanish', 'English', 'USA', 'India', 'good', '20220616']
# ['124', 'darbassom07@vodafone.com ', 'Cobb', 1994, 5.0, 6.399797979797981, '6930', 66, '', 'Ron Shelton', 'Drama', 'Biography', 'Tommy Lee Jones', 'Robert Wuhl', '', 'English', 'USA', '', 'good', '20220616']
# ['125', 'shuforfog38@orange.com', 'The Girl Is in Trouble', 2015, 6.0, 4.901298701298702, '847', 55, '', 'Julius Onah', 'Crime', 'Action', 'Columbus Short', 'Wilmer Valderrama', '', 'English', 'USA', '', 'good', '20220616']
# ['126', 'julzanbai012@hotmail.com', 'Person to Person', 2017, 4.0, 5.698733233979136, '1342', 53, '', 'Dustin Guy Defa', 'Drama', 'Comedy', 'Abbi Jacobson', 'Michael Cera', '', 'English', 'USA', '', 'good', '20220616']
# ['133', 'juaaouesq86543@vodafone.com ', 'Micki + Maude', 1984, 5.0, 5.999619337647506, '2627', 64, '', 'Blake Edwards', 'Romance', 'Comedy', 'Dudley Moore', 'Amy Irving', '', 'English', 'USA', '', 'good', '20220616']
# ['137', 'peltuegus5983@jazztel.com', 'Daltry Calhoun', 2005, 8.0, 5.101294065149487, '2241', 30, '', 'Katrina Holden Bronson', 'Drama', 'Comedy', 'Elizabeth Banks', 'Johnny Knoxville', '', 'English', 'USA', '', 'good', '20220616']
# ['140', 'peltuegus5983@jazztel.com', 'Dreamgirls', 2006, 6.0, 6.499992537313433, '67000', 76, '', 'Bill Condon', 'Music', 'Drama', 'Jamie Foxx', 'Beyoncé', '', 'English', 'USA', '', 'good', '20220616']
# ['147', 'mimguarez39608@orange.com', 'The Secret of My Success', 1987, 2.0, 6.4998426243267815, '28594', 36, '', 'Herbert Ross', 'Romance', 'Comedy', 'Michael J. Fox', 'Helen Slater', '', 'English', 'USA', '', 'good', '20220616']
# ['148', 'gemyanbic970@hotmail.com', 'The Zero Theorem', 2013, 10.0, 6.100088044067184, '44296', 50, '', 'Terry Gilliam', 'Drama', 'Comedy', 'Christoph Waltz', 'Gwendoline Christie', '', 'English', 'UK', 'Romania', 'good', '20220616']
# ['154', 'joasantey6285@orange.com', 'Krystal', 2017, 7.0, 5.401336675020886, '1197', 39, '', 'William H. Macy', 'Drama', 'Comedy', 'Rosario Dawson', 'Nick Robinson', '', 'English', 'USA', '', 'good', '20220616']
# ['156', 'vlabonalb299970@digi.com', 'Feral', 2017, 5.0, 4.500202675314147, '2467', 41, '', 'Mark Young', 'Drama', 'Action', 'Scout Taylor-Compton', 'Olivia Luccardi', '', 'English', 'USA', '', 'good', '20220616']
# ['177', 'peltuegus5983@jazztel.com', 'This Is the End', 2013, 5.0, 6.59999574011507, '375597', 67, 'Seth Rogen', 'Evan Goldberg', '', 'Comedy', 'James Franco', 'Jonah Hill', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['183', 'marchesui6@vodafone.com ', 'Star Trek: First Contact', 1996, 10.0, 7.600020832429148, '115205', 71, '', 'Jonathan Frakes', 'Adventure', 'Action', 'Patrick Stewart', 'Jonathan Frakes', '', 'English', 'USA', '', 'good', '20220616']
# ['185', 'raqmirbra6@digi.com', 'The Intruder', 2019, 2.0, 5.599683683331868, '11381', 39, '', 'Deon Taylor', 'Horror', 'Drama', 'Michael Ealy', 'Joseph Sikora', '', 'English', 'USA', 'Canada', 'good', '20220616']
# ['186', 'temifkalo07834@orange.com', 'Urban Cowboy', 1980, 2.0, 6.299661230599543, '12693', 61, '', 'James Bridges', 'Romance', 'Drama', 'John Travolta', 'Debra Winger', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['189', 'anaustdob5@digi.com', 'Wolfen', 1981, 10.0, 6.300423971582445, '8727', 64, '', 'Michael Wadleigh', 'Thriller', 'Horror', 'Albert Finney', 'Diane Venora', '', 'English', 'USA', '', 'good', '20220616']
# ['191', 'temifkalo07834@orange.com', 'School Daze', 1988, 6.0, 6.0, '6025', 49, '', 'Spike Lee', 'Drama', 'Comedy', 'Laurence Fishburne', 'Giancarlo Esposito', '', 'English', 'USA', '', 'good', '20220616']
# ['195', 'fedarrker26@jazztel.com', 'My Little Pony: The Movie', 2017, 7.0, 6.100157425223019, '5717', 39, '', 'Jayson Thiessen', 'Adventure', 'Animation', 'Uzo Aduba', 'Ashleigh Ball', '', 'English', 'USA', 'Canada', 'good', '20220616']
# ['196', 'anaustdob5@digi.com', 'The Guru', 2002, 1.0, 5.299706524706525, '14652', 47, '', 'Daisy von Scherler Mayer', 'Music', 'Comedy', 'Jimi Mistry', 'Heather Graham', 'Hindi', 'English', 'UK', 'France', 'good', '20220616']
# ['198', 'yesbelhar0221@gmail.com', 'Videodrome', 1983, 6.0, 7.199985051572076, '80276', 60, '', 'David Cronenberg', 'Sci-Fi', 'Horror', 'James Woods', 'Sonja Smits', '', 'English', 'Canada', 'France', 'good', '20220616']
# ['203', 'vlabonalb299970@digi.com', 'Lord of War', 2005, 10.0, 7.600008335822502, '287914', 62, '', 'Andrew Niccol', 'Crime', 'Action', 'Nicolas Cage', 'Bridget Moynahan', 'Ukrainian', 'English', 'USA', 'Germany', 'good', '20220616']
# ['207', 'tarbelmor2@digi.com', 'E.T. the Extra-Terrestrial', 1982, 1.0, 7.799981023926596, '358346', 91, '', 'Steven Spielberg', 'Sci-Fi', 'Family', 'Dee Wallace', 'Henry Thomas', '', 'English', 'USA', '', 'good', '20220616']
# ['211', 'naytracam020337@digi.com', 'Are We Not Cats', 2016, 8.0, 5.804014598540146, '548', 68, '', 'Xander Robin', 'Horror', 'Comedy', 'Michael Patrick Nicholson', 'Chelsea Lopez', '', 'English', 'USA', '', 'good', '20220616']
# ['213', 'manortlle3879@gmail.com', 'The Last Man', 2000, 5.0, 5.299457504520795, '553', 32, '', 'Harry Ralston', 'Comedy', 'Action', 'David Arnott', 'Jeri Ryan', '', 'English', 'USA', '', 'good', '20220616']
# ['214', 'hercamare50@vodafone.com ', '8MM', 1999, 1.0, 6.4999543265238335, '120420', 19, '', 'Joel Schumacher', 'Thriller', 'Mystery', 'Nicolas Cage', 'Joaquin Phoenix', '', 'English', 'Germany', 'USA', 'good', '20220616']
# ['217', 'adachusan1@movistar.com', 'Bang the Drum Slowly', 1973, 6.0, 6.899826723142088, '5194', 80, '', 'John D. Hancock', 'Sport', 'Drama', 'Michael Moriarty', 'Robert De Niro', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['227', 'emigraloz8@hotmail.com', 'Christmas in the Clouds', 2001, 3.0, 6.494942196531792, '692', 56, '', 'Kate Montgomery', 'Family', 'Comedy', 'Timothy Vahle', 'Sam Vlahos', '', 'English', 'USA', '', 'good', '20220616']
# ['243', 'adachusan1@movistar.com', 'The Valley', 2017, 2.0, 7.008928571428571, '56', 33, '', 'Saila Kariat', 'Mystery', 'Drama', 'Alyy Khan', 'Suchitra Pillai', '', 'English', 'USA', '', 'good', '20220616']
# ['246', 'vikmoulir84896@gmail.com', 'Gone Baby Gone', 2007, 7.0, 7.599997536885144, '243594', 72, '', 'Ben Affleck', 'Drama', 'Crime', 'Casey Affleck', 'Michelle Monaghan', '', 'English', 'USA', '', 'good', '20220616']
# ['247', 'siljaugea161@orange.com', 'When We First Met', 2018, 3.0, 6.3999141327406806, '39596', 36, '', 'Ari Sandel', 'Fantasy', 'Comedy', 'Adam Devine', 'Alexandra Daddario', 'Mandarin', 'English', 'USA', '', 'good', '20220616']
# ['251', 'raqmirbra6@digi.com', 'Police Academy 3: Back in Training', 1986, 2.0, 5.399917747242114, '41336', 33, '', 'Jerry Paris', '', 'Comedy', 'Steve Guttenberg', 'Bubba Smith', '', 'English', 'Canada', 'USA', 'good', '20220616']
# ['253', 'guiurdfel76@digi.com', 'Wake', 2003, 1.0, 6.584487534626039, '361', 34, '', 'Roy Finch', '', 'Drama', 'Blake Gibbons', 'Gale Harold', '', 'English', 'USA', '', 'good', '20220616']
# ['261', 'nicpetriu089@movistar.com', 'Face/Off', 1997, 1.0, 7.299981506650267, '340663', 82, '', 'John Woo', 'Crime', 'Action', 'John Travolta', 'Nicolas Cage', 'Latin', 'English', 'USA', '', 'good', '20220616']
# ['269', 'nicpetriu089@movistar.com', 'The Human Centipede III (Final Sequence)', 2015, 1.0, 2.699878675421068, '14012', 5, '', 'Tom Six', 'Horror', 'Comedy', 'Dieter Laser', 'Laurence R. Harvey', '', 'English', 'USA', '', 'good', '20220616']
# ['270', 'alifenvel96289@vodafone.com ', 'Cloudy with a Chance of Meatballs 2', 2013, 10.0, 6.400041383591406, '86991', 59, 'Kris Pearn', 'Cody Cameron', 'Adventure', 'Animation', 'Bill Hader', 'Anna Faris', 'Chinese', 'English', 'USA', '', 'good', '20220616']
# ['272', 'aguherbas3716@gmail.com', 'Every Day', 2018, 2.0, 6.399741024131843, '16990', 52, '', 'Michael Sucsy', 'Fantasy', 'Drama', 'Angourie Rice', 'Justice Smith', '', 'English', 'Canada', 'UK', 'good', '20220616']
# ['273', 'ursridgra182458@movistar.com', 'Battleship', 2012, 8.0, 5.800009481532561, '232030', 41, '', 'Peter Berg', 'Adventure', 'Action', 'Taylor Kitsch', 'Alexander Skarsgård', 'Japanese', 'English', 'USA', '', 'good', '20220616']
# ['281', 'estbouel3440@orange.com', "Dealin' with Idiots", 2013, 4.0, 5.498788368336026, '1238', 43, '', 'Jeff Garlin', '', 'Comedy', 'Jeff Garlin', 'Max Wright', '', 'English', 'USA', '', 'good', '20220616']
# ['283', 'raqmirbra6@digi.com', 'Adam & Steve', 2005, 10.0, 5.901391245334239, '2947', 48, '', 'Craig Chester', 'Drama', 'Comedy', 'Malcolm Gets', 'Cary Curran', '', 'English', 'USA', '', 'good', '20220616']
# ['289', 'angabafah7@vodafone.com ', 'The Brothers McMullen', 1995, 2.0, 6.599417556510885, '7211', 73, '', 'Edward Burns', 'Drama', 'Comedy', 'Shari Albert', 'Maxine Bahns', '', 'English', 'USA', '', 'good', '20220616']
# ['298', 'naytracam020337@digi.com', 'The Postman', 1997, 9.0, 6.100043179821623, '67161', 29, '', 'Kevin Costner', 'Adventure', 'Action', 'Kevin Costner', 'Will Patton', '', 'English', 'USA', '', 'good', '20220616']
# ['299', 'mimguarez39608@orange.com', 'The Vast of Night', 2019, 10.0, 6.700406203840473, '8124', 84, '', 'Andrew Patterson', 'Mystery', 'Drama', 'Sierra McCormick', 'Jake Horowitz', '', 'English', 'USA', '', 'good', '20220616']
# ['306', 'gemyanbic970@hotmail.com', 'The Adventures of Buckaroo Banzai Across the 8th Dimension', 1984, 5.0, 6.299943972762143, '23203', 70, '', 'W.D. Richter', 'Comedy', 'Adventure', 'Peter Weller', 'John Lithgow', '', 'English', 'USA', '', 'good', '20220616']
# ['311', 'guiurdfel76@digi.com', 'Turn the River', 2007, 3.0, 5.79835390946502, '1701', 55, '', 'Chris Eigeman', '', 'Drama', 'Famke Janssen', 'Jaymie Dornan', '', 'English', 'USA', '', 'good', '20220616']
# ['313', 'vikmoulir84896@gmail.com', 'Oliver & Company', 1988, 2.0, 6.699888572783309, '42180', 58, '', 'George Scribner', 'Adventure', 'Animation', 'Joey Lawrence', 'Billy Joel', '', 'English', 'USA', '', 'good', '20220616']
# ['319', 'assaboshe7@vodafone.com ', 'Dirty Dancing: Havana Nights', 2004, 9.0, 6.000114608801956, '26176', 39, '', 'Guy Ferland', 'Music', 'Drama', 'Diego Luna', 'Romola Garai', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['321', 'guemaiiva047323@vodafone.com ', '9 to 5', 1980, 2.0, 6.799818202476992, '26403', 58, '', 'Colin Higgins', '', 'Comedy', 'Jane Fonda', 'Lily Tomlin', 'French', 'English', 'USA', '', 'good', '20220616']
# ['323', 'juaaouesq86543@vodafone.com ', 'D.E.B.S.', 2004, 7.0, 5.300117638917722, '14451', 42, '', 'Angela Robinson', 'Comedy', 'Action', 'Sara Foster', 'Jordana Brewster', '', 'English', 'USA', '', 'good', '20220616']
# ['328', 'marrachac85@movistar.com', 'Margin Call', 2011, 2.0, 7.099954771997659, '112762', 76, '', 'J.C. Chandor', 'Thriller', 'Drama', 'Kevin Spacey', 'Paul Bettany', '', 'English', 'USA', '', 'good', '20220616']
# ['330', 'eleirssas26@gmail.com', 'Wetlands', 2019, 6.0, 4.205142857142857, '350', 37, '', 'Emanuele Della Valle', 'Drama', 'Crime', 'Adewale Akinnuoye-Agbaje', 'Heather Graham', '', 'English', 'USA', '', 'good', '20220616']
# ['331', 'emigraloz8@hotmail.com', 'Private Parts', 1997, 4.0, 6.8999127058186085, '33221', 67, '', 'Betty Thomas', 'Comedy', 'Biography', 'Howard Stern', 'Robin Quivers', '', 'English', 'USA', '', 'good', '20220616']
# ['340', 'angabafah7@vodafone.com ', 'Year One', 2009, 10.0, 4.900056641492671, '90040', 34, '', 'Harold Ramis', '', 'Comedy', 'Jack Black', 'Michael Cera', '', 'English', 'USA', '', 'good', '20220616']
# ['343', 'emigraloz8@hotmail.com', 'Rick', 2003, 7.0, 6.001206272617612, '829', 52, '', 'Curtiss Clayton', 'Drama', 'Comedy', 'Bill Pullman', 'Aaron Stanford', '', 'English', 'USA', '', 'good', '20220616']
# ['348', 'ursridgra182458@movistar.com', 'Shadow: Dead Riot', 2006, 9.0, 4.005452562704472, '917', 33, '', 'Derek Wan', 'Horror', 'Action', 'Tony Todd', 'Carla Greene', '', 'English', 'USA', '', 'good', '20220616']
# ['350', 'fedarrker26@jazztel.com', 'Pandorum', 2009, 4.0, 6.699980856901796, '141043', 28, '', 'Christian Alvart', 'Horror', 'Action', 'Dennis Quaid', 'Ben Foster', 'Vietnamese', 'English', 'Germany', 'UK', 'good', '20220616']
# ['354', 'ursridgra182458@movistar.com', 'The Brothers McMullen', 1995, 7.0, 6.599417556510885, '7211', 73, '', 'Edward Burns', 'Drama', 'Comedy', 'Shari Albert', 'Maxine Bahns', '', 'English', 'USA', '', 'good', '20220616']
# ['357', 'lucboufan4887@hotmail.com', 'Bedazzled', 2000, 7.0, 6.000010580331164, '94515', 49, '', 'Harold Ramis', 'Fantasy', 'Comedy', 'Brendan Fraser', 'Elizabeth Hurley', 'Spanish', 'English', 'USA', 'Germany', 'good', '20220616']
# ['358', 'javriscon547659@gmail.com', 'Snipes', 2001, 7.0, 5.504322766570605, '347', 32, '', 'Rich Murray', 'Drama', 'Action', 'Sam Jones III', 'Nelly', '', 'English', 'USA', '', 'good', '20220616']
# ['362', 'wiosormas415@movistar.com', 'The Favourite', 2018, 4.0, 7.499978040731307, '159386', 91, '', 'Yorgos Lanthimos', 'Comedy', 'Biography', 'Olivia Colman', 'Rachel Weisz', '', 'English', 'Ireland', 'UK', 'good', '20220616']
# ['368', 'guemaiiva047323@vodafone.com ', 'Man of the Century', 1999, 6.0, 6.899222797927461, '1158', 44, '', 'Adam Abraham', 'Romance', 'Comedy', 'Gibson Frazier', 'Cara Buono', 'Chinese', 'Italian', 'USA', '', 'good', '20220616']
# ['369', 'chobunbux37@orange.com', 'Undercover Brother', 2002, 5.0, 5.799975671319527, '32883', 69, '', 'Malcolm D. Lee', 'Comedy', 'Action', 'Eddie Griffin', 'Chris Kattan', '', 'English', 'USA', '', 'good', '20220616']
# ['373', 'hercamare50@vodafone.com ', 'Captain America: The First Avenger', 2011, 5.0, 6.89999734914175, '716749', 66, '', 'Joe Johnston', 'Adventure', 'Action', 'Chris Evans', 'Hayley Atwell', 'Norwegian', 'English', 'USA', '', 'good', '20220616']
# ['376', 'harraeel5@jazztel.com', 'Chuck & Buck', 2000, 5.0, 6.499711316397229, '5196', 76, '', 'Miguel Arteta', 'Drama', 'Comedy', 'Mike White', 'Chris Weitz', '', 'English', 'USA', '', 'good', '20220616']
# ['386', 'pabkarbor59537@hotmail.com', 'All the Right Moves', 1983, 2.0, 5.899742761031594, '15161', 62, '', 'Michael Chapman', 'Romance', 'Drama', 'Tom Cruise', 'Craig T. Nelson', '', 'English', 'USA', '', 'good', '20220616']
# ['393', 'marrachac85@movistar.com', 'The Wave', 2019, 2.0, 5.99802371541502, '2024', 51, '', 'Gille Klabin', 'Thriller', 'Sci-Fi', 'Justin Long', 'Tommy Flanagan', '', 'English', 'USA', '', 'good', '20220616']
# ['395', 'ivamongra1@digi.com', 'King of the Mountain', 1981, 10.0, 5.513846153846154, '325', 48, '', 'Noel Nosseck', '', 'Drama', 'Harry Hamlin', 'Joseph Bottoms', '', 'English', 'USA', '', 'good', '20220616']
# ['400', 'siljaugea161@orange.com', 'Beneath', 2013, 8.0, 3.70106094251172, '4053', 40, '', 'Ben Ketai', 'Drama', 'Adventure', 'Brent Briscoe', 'Kurt Caceres', '', 'English', 'USA', '', 'good', '20220616']
# ['404', 'marrachac85@movistar.com', 'The Bad News Bears', 1976, 2.0, 7.29973058153721, '19672', 84, '', 'Michael Ritchie', 'Drama', 'Comedy', 'Walter Matthau', "Tatum O'Neal", 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['412', 'josdasvig2879@orange.com', 'Drive Me Crazy', 1999, 5.0, 5.799954843079702, '17716', 42, '', 'John Schultz', 'Drama', 'Comedy', 'Melissa Joan Hart', 'Adrian Grenier', '', 'English', 'USA', '', 'good', '20220616']
# ['413', 'aleechgua159671@movistar.com', 'Journey to the Center of the Earth', 2008, 7.0, 5.800010873701952, '110358', 57, '', 'Eric Brevig', 'Adventure', 'Action', 'Brendan Fraser', 'Josh Hutcherson', 'Icelandic', 'English', 'USA', '', 'good', '20220616']
# ['414', 'saafrarei8189@jazztel.com', 'House of the Dead', 2003, 4.0, 2.0000563443768318, '35496', 15, '', 'Uwe Boll', 'Adventure', 'Action', 'Jonathan Cherry', 'Tyron Leitso', '', 'English', 'Germany', 'Canada', 'good', '20220616']
# ['417', 'xesmalref0@digi.com', "Breakin'", 1984, 7.0, 5.800212089077412, '5658', 53, '', 'Joel Silberg', 'Drama', 'Comedy', 'Lucinda Dickey', 'Adolfo Quinones', '', 'English', 'USA', '', 'good', '20220616']
# ['421', 'estgubalz27234@gmail.com', 'The Tuxedo', 2002, 8.0, 5.400033625617548, '77322', 30, '', 'Kevin Donovan', 'Comedy', 'Action', 'Jackie Chan', 'Jennifer Love Hewitt', 'Cantonese', 'English', 'USA', '', 'good', '20220616']
# ['441', 'belcozkal350559@vodafone.com ', 'Superman III', 1983, 6.0, 5.000015974440895, '62600', 44, '', 'Richard Lester', 'Adventure', 'Action', 'Christopher Reeve', 'Richard Pryor', 'Italian', 'English', 'UK', 'USA', 'good', '20220616']
# ['450', 'nicpetriu089@movistar.com', 'Home Fries', 1998, 4.0, 5.099860970677452, '7912', 45, '', 'Dean Parisot', 'Romance', 'Comedy', 'Drew Barrymore', "Catherine O'Hara", '', 'English', 'USA', '', 'good', '20220616']
# ['464', 'tescitel7807@orange.com', 'Thief', 1981, 10.0, 7.400109367770161, '23773', 78, '', 'Michael Mann', 'Crime', 'Action', 'James Caan', 'Tuesday Weld', '', 'English', 'USA', '', 'good', '20220616']
# ['466', 'chobunbux37@orange.com', 'The Return of the Pink Panther', 1975, 1.0, 7.099748162827182, '24222', 61, '', 'Blake Edwards', 'Crime', 'Comedy', 'Peter Sellers', 'Christopher Plummer', '', 'English', 'UK', 'USA', 'good', '20220616']
# ['467', 'harraeel5@jazztel.com', 'Coming Through the Rye', 2015, 9.0, 6.303349875930521, '806', 64, '', 'James Steven Sadwith', '', 'Drama', 'Alex Wolff', 'Stefania LaVie Owen', '', 'English', 'USA', '', 'good', '20220616']
# ['468', 'jossatcor68@gmail.com', 'Sister Act 2: Back in the Habit', 1993, 6.0, 5.60000844880027, '47344', 38, '', 'Bill Duke', 'Family', 'Comedy', 'Whoopi Goldberg', 'Kathy Najimy', '', 'English', 'USA', '', 'good', '20220616']
# ['469', 'ainsalalp45038@movistar.com', 'Computer Chess', 2013, 3.0, 6.29922788956481, '4274', 74, '', 'Andrew Bujalski', '', 'Comedy', 'Kriss Schludermann', 'Tom Fletcher', '', 'English', 'USA', '', 'good', '20220616']
# ['486', 'pabkarbor59537@hotmail.com', 'Toad Road', 2012, 6.0, 5.100758853288364, '1186', 54, '', 'Jason Banker', '', 'Horror', 'James Davidson', 'Sara Anne Jones', '', 'English', 'USA', '', 'good', '20220616']
# ['488', 'javriscon547659@gmail.com', 'In the Heart of the Sea', 2015, 6.0, 6.899992263189113, '116327', 47, '', 'Ron Howard', 'Adventure', 'Action', 'Chris Hemsworth', 'Benjamin Walker', '', 'English', 'USA', 'Australia', 'good', '20220616']
# ['495', 'anaustdob5@digi.com', 'Point Blank', 2019, 3.0, 5.699742955064737, '10504', 37, '', 'Joe Lynch', 'Thriller', 'Action', 'Frank Grillo', 'Stuart F. Wilson', '', 'English', 'France', 'USA', 'good', '20220616']
# ['502', 'jaighasal61@digi.com', 'Made of Honor', 2008, 1.0, 5.89992575532592, '65998', 37, '', 'Paul Weiland', 'Romance', 'Comedy', 'Patrick Dempsey', 'Michelle Monaghan', '', 'English', 'USA', 'UK', 'good', '20220616']
# ['519', 'ailestben8@jazztel.com', 'Superstar', 1999, 2.0, 5.19981824378053, '17606', 42, '', 'Bruce McCulloch', 'Romance', 'Comedy', 'Molly Shannon', 'Will Ferrell', '', 'English', 'USA', '', 'good', '20220616']
# ['524', 'assaboshe7@vodafone.com ', 'Night Catches Us', 2010, 5.0, 6.199181446111869, '1466', 65, '', 'Tanya Hamilton', 'Romance', 'Drama', 'Anthony Mackie', 'Jamara Griffin', '', 'English', 'USA', '', 'good', '20220616']
# ['525', 'ailestben8@jazztel.com', 'The Main Event', 2020, 5.0, 4.700214132762313, '1401', 52, '', 'Jay Karas', 'Comedy', 'Action', 'Seth Carr', 'Tichina Arnold', '', 'English', 'USA', '', 'good', '20220616']
# ['537', 'alifenvel96289@vodafone.com ', 'Blood Fest', 2018, 3.0, 5.299410558687852, '3902', 54, '', 'Owen Egerton', 'Horror', 'Comedy', 'Robbie Kay', 'Jacob Batalon', '', 'English', 'USA', '', 'good', '20220616']
# ['539', 'aguherbas3716@gmail.com', 'Stars in Shorts', 2012, 8.0, 6.407960199004975, '201', 49, 'Robert Festinger', 'Jacob Chase', '', 'Comedy', 'Lily Tomlin', 'Jesse Tyler Ferguson', '', 'English', 'USA', '', 'good', '20220616']
# ['543', 'eleirssas26@gmail.com', 'Stroker Ace', 1983, 7.0, 4.900605885747259, '3466', 30, '', 'Hal Needham', 'Comedy', 'Action', 'Burt Reynolds', 'Ned Beatty', '', 'English', 'USA', '', 'good', '20220616']
# ['549', 'chobunbux37@orange.com', 'Welcome to Sarajevo', 1997, 2.0, 6.799292139802389, '6781', 72, '', 'Michael Winterbottom', 'War', 'Drama', 'Stephen Dillane', 'Woody Harrelson', 'Serbian', 'English', 'UK', 'USA', 'good', '20220616']
# ['554', 'raubetpen522@jazztel.com', 'Into the Night', 1985, 2.0, 6.499576350969686, '10622', 41, '', 'John Landis', 'Comedy', 'Action', 'Jeff Goldblum', 'Stacey Pickren', 'Persian', 'English', 'USA', '', 'good', '20220616']
# ['558', 'julcarbad6@jazztel.com', 'X-Men: Dark Phoenix', 2019, 9.0, 5.800022772721126, '140519', 43, '', 'Simon Kinberg', 'Adventure', 'Action', 'James McAvoy', 'Michael Fassbender', 'French', 'English', 'USA', 'Canada', 'good', '20220616']
# ['559', 'saafrarei8189@jazztel.com', 'I Went Down', 1997, 5.0, 6.899035532994924, '1970', 69, '', 'Paddy Breathnach', 'Comedy', 'Action', 'Peter McDonald', 'Antoine Byrne', '', 'English', 'Ireland', 'UK', 'good', '20220616']
# ['568', 'peltuegus5983@jazztel.com', 'Torn Curtain', 1966, 2.0, 6.699801788124157, '23712', 55, '', 'Alfred Hitchcock', 'Thriller', 'Romance', 'Paul Newman', 'Julie Andrews', 'German', 'English', 'USA', '', 'good', '20220616']
# ['569', 'hercamare50@vodafone.com ', 'Surviving Christmas', 2004, 10.0, 5.400210613067168, '21841', 19, '', 'Mike Mitchell', 'Romance', 'Comedy', 'Ben Affleck', 'James Gandolfini', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['572', 'julzanbai012@hotmail.com', 'Bad Words', 2013, 10.0, 6.60007465636116, '45542', 57, '', 'Jason Bateman', 'Drama', 'Comedy', 'Jason Bateman', 'Kathryn Hahn', '', 'English', 'USA', '', 'good', '20220616']
# ['573', 'joasantey6285@orange.com', 'Shadow Magic', 2000, 5.0, 6.697708894878706, '742', 66, '', 'Ann Hu', 'History', 'Drama', 'Jared Harris', 'Yu Xia', 'Mandarin', 'English', 'China', 'Germany', 'good', '20220616']
# ['574', 'raubetpen522@jazztel.com', 'Get Shorty', 1995, 1.0, 6.899920239012586, '73971', 82, '', 'Barry Sonnenfeld', 'Crime', 'Comedy', 'John Travolta', 'Gene Hackman', '', 'English', 'USA', '', 'good', '20220616']
# ['585', 'hercamare50@vodafone.com ', 'Mulan', 1998, 2.0, 7.59997677697603, '241140', 71, 'Barry Cook', 'Tony Bancroft', 'Adventure', 'Animation', 'Miguel Ferrer', 'Harvey Fierstein', 'Mandarin', 'English', 'USA', '', 'good', '20220616']
# ['586', 'levbouel8567@vodafone.com ', 'Arlington Road', 1999, 1.0, 7.19992193598751, '79422', 65, '', 'Mark Pellington', 'Drama', 'Crime', 'Jeff Bridges', 'Tim Robbins', '', 'English', 'USA', '', 'good', '20220616']
# ['591', 'zaibelgar033755@digi.com', 'Motherhood', 2009, 10.0, 4.6012546468401485, '4304', 34, '', 'Katherine Dieckmann', 'Drama', 'Comedy', 'Uma Thurman', 'Anthony Edwards', '', 'English', 'USA', '', 'good', '20220616']
# ['593', 'mimguarez39608@orange.com', 'Underworld', 2003, 5.0, 6.999991927346115, '247750', 42, '', 'Len Wiseman', 'Fantasy', 'Action', 'Kate Beckinsale', 'Scott Speedman', '', 'English', 'USA', 'UK', 'good', '20220616']
# ['594', 'manortlle3879@gmail.com', 'Fast Colour', 2018, 6.0, 6.0, '3668', 64, '', 'Julia Hart', 'Sci-Fi', 'Drama', 'Gugu Mbatha-Raw', 'David Strathairn', '', 'English', 'USA', '', 'good', '20220616']
# ['595', 'mimguarez39608@orange.com', 'K-11', 2012, 4.0, 5.0992889463477695, '1547', 21, '', 'Jules Stewart', '', 'Drama', 'Goran Visnjic', 'Kate del Castillo', '', 'English', 'USA', '', 'good', '20220616']
# ['597', 'saafrarei8189@jazztel.com', 'The Glass House', 2001, 8.0, 5.800069633474711, '31594', 34, '', 'Daniel Sackheim', 'Drama', 'Crime', 'Leelee Sobieski', 'Diane Lane', 'Spanish', 'English', 'USA', '', 'good', '20220616']
# ['599', 'temifkalo07834@orange.com', 'Permanent Midnight', 1998, 6.0, 6.299956082564778, '6831', 57, '', 'David Veloz', 'Drama', 'Biography', 'Ben Stiller', 'Maria Bello', '', 'English', 'USA', '', 'good', '20220616']
# ['600', 'estgubalz27234@gmail.com', 'Appaloosa', 2008, 6.0, 6.699987797437462, '57365', 64, '', 'Ed Harris', 'Crime', 'Action', 'Robert Jauregui', 'Jeremy Irons', 'Apache languages', 'English', 'USA', '', 'good', '20220616']
# ['603', 'jaibelvec58@movistar.com', 'Midnight Sun', 2018, 9.0, 6.600115019649191, '20866', 38, '', 'Scott Speer', 'Romance', 'Drama', 'Bella Thorne', 'Patrick Schwarzenegger', '', 'English', 'USA', '', 'good', '20220616']
# ['605', 'annroddio997@gmail.com', 'The Jackal', 1997, 2.0, 6.399957697188786, '104012', 36, '', 'Michael Caton-Jones', 'Crime', 'Action', 'Bruce Willis', 'Richard Gere', 'Russian', 'English', 'USA', 'UK', 'good', '20220616']
# ['606', 'estgubalz27234@gmail.com', "Clifford's Really Big Movie", 2004, 5.0, 5.399465240641711, '748', 49, 'Steve Trenbirth', 'Robert C. Ramirez', 'Adventure', 'Animation', 'John Ritter', 'Wayne Brady', '', 'English', 'USA', '', 'good', '20220616']

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, DoubleType, FloatType

movieSchema = StructType([  
    StructField('register', StringType(), True),
    StructField('user', StringType(), True),
    StructField('title', StringType(), True),
    StructField('year', IntegerType(), True),
    StructField('score', FloatType(), True),
    StructField('users_rating', FloatType(), True),
    StructField('votes', StringType(), True),
    StructField('metascore', IntegerType(), True),
    StructField('codirector', StringType(), True),
    StructField('director', StringType(), True),
    StructField('cogenre', StringType(), True),
    StructField('genre', StringType(), True),
    StructField('mainactor', StringType(), True),
    StructField('secactor', StringType(), True),
    StructField('seclanguage', StringType(), True),
    StructField('vose', StringType(), True),
    StructField('country', StringType(), True),
    StructField('seccountry', StringType(), True), 
    StructField('validationOut', StringType(), True),
    StructField('date', StringType(), True)
])

dsMovies = spark.createDataFrame(rddMoviesOk, schema = movieSchema).drop('validationOut').drop('register')

dsMovies.printSchema()
dsMovies.show()
dsMovies.repartition(4).write.parquet("./staging/moviesokParquet/", mode = "overwrite", partitionBy = ["date"])
# Out:
# root
#  |-- user: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- score: float (nullable = true)
#  |-- users_rating: float (nullable = true)
#  |-- votes: string (nullable = true)
#  |-- metascore: integer (nullable = true)
#  |-- codirector: string (nullable = true)
#  |-- director: string (nullable = true)
#  |-- cogenre: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- mainactor: string (nullable = true)
#  |-- secactor: string (nullable = true)
#  |-- seclanguage: string (nullable = true)
#  |-- vose: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- seccountry: string (nullable = true)
#  |-- date: string (nullable = true)
#
# +--------------------+--------------------+----+-----+------------+------+---------+-----------+-----------------+---------+---------+--------------------+------------------+-----------+-------+-------+-----------+--------+
# |                user|               title|year|score|users_rating| votes|metascore| codirector|         director|  cogenre|    genre|           mainactor|          secactor|seclanguage|   vose|country| seccountry|    date|
# +--------------------+--------------------+----+-----+------------+------+---------+-----------+-----------------+---------+---------+--------------------+------------------+-----------+-------+-------+-----------+--------+
# |julcarbad6@jazzte...|            Serenity|2005|  2.0|         7.8| 32119|       74|           |      Joss Whedon|Adventure|   Action|      Nathan Fillion|       Gina Torres|   Mandarin|English|    USA|           |20220616|
# |eleirssas26@gmail...|   The Ides of March|2011|  8.0|    7.100004|211633|       67|           |   George Clooney| Thriller|    Drama|        Ryan Gosling|    George Clooney|           |English|    USA|           |20220616|
# |josdasvig2879@ora...|        The Ring Two|2005|  9.0|     5.40004| 89640|       44|           |     Hideo Nakata|  Mystery|   Horror|         Naomi Watts|       Simon Baker|           |English|    USA|           |20220616|
# |guemaiiva047323@v...|Madagascar 3: Eur...|2012|  7.0|    6.800001|157328|       60|Tom McGrath|     Eric Darnell|Adventure|Animation|         Ben Stiller|        Chris Rock|    Spanish|English|    USA|           |20220616|
# |joasantey6285@ora...|    Where Hope Grows|2014| 10.0|   6.6011796|  2882|       41|           |    Chris Dowling|   Family|    Drama|   Kristoffer Polaha|   David DeSanctis|           |English|    USA|           |20220616|
# |alifenvel96289@vo...|        White Rabbit|2018|  7.0|    5.701114|  1167|       61|           |       Daryl Wein|    Drama|   Comedy|         Vivian Bang|        Nana Ghana|           |English|    USA|           |20220616|
# |marmaybaz2601@mov...|            Thin Ice|2011|  1.0|    6.198861|  4566|       60|           |    Jill Sprecher|    Crime|   Comedy|        Greg Kinnear|  John Paul Gamoke|           |English|    USA|           |20220616|
# |jacavioli86730@vo...|        In the Blood|2014|  8.0|   5.7002087| 11014|       40|           |   John Stockwell|    Crime|   Action|         Gina Carano|      Cam Gigandet|           |English|     UK|Puerto Rico|20220616|
# |humpenpor2@orange...|             Amadeus|1984| 10.0|    8.300005|357391|       88|           |     Milos Forman|    Drama|Biography|   F. Murray Abraham|         Tom Hulce|    Italian|English|    USA|     France|20220616|
# |guiurdfel76@digi.com|         The Pyramid|2014|  5.0|   4.6000175| 22560|       24|           |Grégory Levasseur|Adventure|   Action|      Ashley Hinshaw|      Denis O'Hare|           |English|    USA|    Morocco|20220616|
# |aleechgua159671@m...|Rogue One: A Star...|2016|  7.0|   7.7999983|532459|       65|           |   Gareth Edwards|Adventure|   Action|      Felicity Jones|        Diego Luna|           |English|    USA|           |20220616|
# |gemyanbic970@hotm...|   The African Queen|1951|  9.0|    7.700019| 69512|       91|           |      John Huston|    Drama|Adventure|     Humphrey Bogart| Katharine Hepburn|     German|English|     UK|        USA|20220616|
# |alifenvel96289@vo...|              Aniara|2018|  2.0|   6.1991057|  4697|       61| Hugo Lilja|   Pella Kagerman|   Sci-Fi|    Drama|      Emelie Garbers|   Bianca Cruzeiro|    Spanish|Swedish| Sweden|    Denmark|20220616|
# | adidialar3@digi.com|              Sliver|1993| 10.0|   5.0001774| 28156|       38|           |    Phillip Noyce| Thriller|    Drama|        Sharon Stone|   William Baldwin|           |English|    USA|           |20220616|
# | xesmalref0@digi.com|         The Hollars|2016| 10.0|    6.500318| 11003|       53|           |   John Krasinski|    Drama|   Comedy|    Margo Martindale|    Sharlto Copley|           |English|    USA|           |20220616|
# |yahkniple6@orange...|             Bandits|2001|  5.0|   6.4999766| 64286|       60|           |   Barry Levinson|    Crime|   Comedy|        Bruce Willis|Billy Bob Thornton|           |English|    USA|           |20220616|
# |julcarbad6@jazzte...|            Sabotage|2014|  4.0|   5.6999707| 57743|       41|           |       David Ayer|    Crime|   Action|Arnold Schwarzene...|   Sam Worthington|    Spanish|English|    USA|           |20220616|
# | adidialar3@digi.com|           Labor Day|2013|  3.0|    6.899905| 41231|       52|           |    Jason Reitman|  Romance|    Drama|        Kate Winslet|       Josh Brolin|           |English|    USA|           |20220616|
# |gemyanbic970@hotm...|       Opening Night|1977| 10.0|    8.000234|  8574|       69|           |  John Cassavetes|         |    Drama|       Gena Rowlands|   John Cassavetes|           |English|    USA|           |20220616|
# |julharsel07108@or...|   The Gumball Rally|1976| 10.0|   6.3010383|  3563|       37|           |     Charles Bail|         |   Comedy|    Michael Sarrazin|     Norman Burton|    Italian|English|    USA|           |20220616|
# +--------------------+--------------------+----+-----+------------+------+---------+-----------+-----------------+---------+---------+--------------------+------------------+-----------+-------+-------+-----------+--------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col

dsMoviesParquet.registerTempTable("movies")
